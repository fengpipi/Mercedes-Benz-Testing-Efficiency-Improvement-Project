# %%
from sklearn import linear_model
import numpy as np
import sklearn.metrics as metrics
import matplotlib.pyplot as plt
import pandas as pd
from sklearn import preprocessing
from sklearn.metrics import accuracy_score
from sklearn.model_selection import train_test_split
from sklearn import datasets
from sklearn.metrics import classification_report
from sklearn.metrics import mean_squared_error
from sklearn.metrics import r2_score
from sklearn.model_selection import GridSearchCV
from sklearn.svm import SVR
from sklearn.pipeline import make_pipeline
from sklearn.preprocessing import StandardScaler
import pylab as pl

# %%
def file_to_numpy(filename):
    """
    Read an input file and convert it to numpy
    """
    df = pd.read_csv(filename)
    return df.to_numpy()

file = pd.read_csv("train.csv")
y = file.iloc[:, 1:2]
x = pd.read_csv("x_transformed.csv")
x = x.iloc[:, 1:]

xHatNames = x.head(0)
xHatNames = xHatNames.T
x = x.to_numpy()
y = y.to_numpy()
y = y.T[0]
# print(y)
# print(len(x[0]))
# print(xHatNames)

xTrain, xTest, yTrain, yTest = train_test_split(x, y, test_size=0.3, random_state=40)

# %%
# the best parameters
clf = GridSearchCV(
        SVR(), 
        [{'kernel': ['linear', 'poly', 'rbf', 'sigmoid'],
          'degree': [2, 3, 4], 'C': [0.5, 0.6, 0.7, 0.8, 0.9, 1.0], 
          'epsilon': [0.1, 0.15, 0.2, 0.25, 0.3]}], cv=3, scoring='r2')
clf.fit(xTrain, yTrain)
means = clf.cv_results_['mean_test_score']
for mean, params in zip(means, clf.cv_results_['params']):
    print("%0.3f for %r" % (mean, params))
print("Best parameters set found on development set:")
print()
print(clf.best_params_)
# Out:
# 0.550 for {'C': 0.5, 'degree': 2, 'epsilon': 0.1, 'kernel': 'linear'}
# 0.500 for {'C': 0.5, 'degree': 2, 'epsilon': 0.1, 'kernel': 'poly'}
# 0.462 for {'C': 0.5, 'degree': 2, 'epsilon': 0.1, 'kernel': 'rbf'}
# 0.430 for {'C': 0.5, 'degree': 2, 'epsilon': 0.1, 'kernel': 'sigmoid'}
# 0.550 for {'C': 0.5, 'degree': 2, 'epsilon': 0.15, 'kernel': 'linear'}
# 0.500 for {'C': 0.5, 'degree': 2, 'epsilon': 0.15, 'kernel': 'poly'}
# 0.462 for {'C': 0.5, 'degree': 2, 'epsilon': 0.15, 'kernel': 'rbf'}
# 0.431 for {'C': 0.5, 'degree': 2, 'epsilon': 0.15, 'kernel': 'sigmoid'}
# 0.550 for {'C': 0.5, 'degree': 2, 'epsilon': 0.2, 'kernel': 'linear'}
# 0.500 for {'C': 0.5, 'degree': 2, 'epsilon': 0.2, 'kernel': 'poly'}
# 0.462 for {'C': 0.5, 'degree': 2, 'epsilon': 0.2, 'kernel': 'rbf'}
# 0.431 for {'C': 0.5, 'degree': 2, 'epsilon': 0.2, 'kernel': 'sigmoid'}
# 0.550 for {'C': 0.5, 'degree': 2, 'epsilon': 0.25, 'kernel': 'linear'}
# 0.500 for {'C': 0.5, 'degree': 2, 'epsilon': 0.25, 'kernel': 'poly'}
# 0.462 for {'C': 0.5, 'degree': 2, 'epsilon': 0.25, 'kernel': 'rbf'}
# 0.431 for {'C': 0.5, 'degree': 2, 'epsilon': 0.25, 'kernel': 'sigmoid'}
# 0.550 for {'C': 0.5, 'degree': 2, 'epsilon': 0.3, 'kernel': 'linear'}
# 0.500 for {'C': 0.5, 'degree': 2, 'epsilon': 0.3, 'kernel': 'poly'}
# 0.462 for {'C': 0.5, 'degree': 2, 'epsilon': 0.3, 'kernel': 'rbf'}
# 0.431 for {'C': 0.5, 'degree': 2, 'epsilon': 0.3, 'kernel': 'sigmoid'}
# 0.550 for {'C': 0.5, 'degree': 3, 'epsilon': 0.1, 'kernel': 'linear'}
# 0.500 for {'C': 0.5, 'degree': 3, 'epsilon': 0.1, 'kernel': 'poly'}
# 0.462 for {'C': 0.5, 'degree': 3, 'epsilon': 0.1, 'kernel': 'rbf'}
# 0.430 for {'C': 0.5, 'degree': 3, 'epsilon': 0.1, 'kernel': 'sigmoid'}
# 0.550 for {'C': 0.5, 'degree': 3, 'epsilon': 0.15, 'kernel': 'linear'}
# 0.500 for {'C': 0.5, 'degree': 3, 'epsilon': 0.15, 'kernel': 'poly'}
# 0.462 for {'C': 0.5, 'degree': 3, 'epsilon': 0.15, 'kernel': 'rbf'}
# 0.431 for {'C': 0.5, 'degree': 3, 'epsilon': 0.15, 'kernel': 'sigmoid'}
# 0.550 for {'C': 0.5, 'degree': 3, 'epsilon': 0.2, 'kernel': 'linear'}
# 0.500 for {'C': 0.5, 'degree': 3, 'epsilon': 0.2, 'kernel': 'poly'}
# 0.462 for {'C': 0.5, 'degree': 3, 'epsilon': 0.2, 'kernel': 'rbf'}
# 0.431 for {'C': 0.5, 'degree': 3, 'epsilon': 0.2, 'kernel': 'sigmoid'}
# 0.550 for {'C': 0.5, 'degree': 3, 'epsilon': 0.25, 'kernel': 'linear'}
# 0.499 for {'C': 0.5, 'degree': 3, 'epsilon': 0.25, 'kernel': 'poly'}
# 0.462 for {'C': 0.5, 'degree': 3, 'epsilon': 0.25, 'kernel': 'rbf'}
# 0.431 for {'C': 0.5, 'degree': 3, 'epsilon': 0.25, 'kernel': 'sigmoid'}
# 0.550 for {'C': 0.5, 'degree': 3, 'epsilon': 0.3, 'kernel': 'linear'}
# 0.499 for {'C': 0.5, 'degree': 3, 'epsilon': 0.3, 'kernel': 'poly'}
# 0.462 for {'C': 0.5, 'degree': 3, 'epsilon': 0.3, 'kernel': 'rbf'}
# 0.431 for {'C': 0.5, 'degree': 3, 'epsilon': 0.3, 'kernel': 'sigmoid'}
# 0.550 for {'C': 0.5, 'degree': 4, 'epsilon': 0.1, 'kernel': 'linear'}
# 0.489 for {'C': 0.5, 'degree': 4, 'epsilon': 0.1, 'kernel': 'poly'}
# 0.462 for {'C': 0.5, 'degree': 4, 'epsilon': 0.1, 'kernel': 'rbf'}
# 0.430 for {'C': 0.5, 'degree': 4, 'epsilon': 0.1, 'kernel': 'sigmoid'}
# 0.550 for {'C': 0.5, 'degree': 4, 'epsilon': 0.15, 'kernel': 'linear'}
# 0.489 for {'C': 0.5, 'degree': 4, 'epsilon': 0.15, 'kernel': 'poly'}
# 0.462 for {'C': 0.5, 'degree': 4, 'epsilon': 0.15, 'kernel': 'rbf'}
# 0.431 for {'C': 0.5, 'degree': 4, 'epsilon': 0.15, 'kernel': 'sigmoid'}
# 0.550 for {'C': 0.5, 'degree': 4, 'epsilon': 0.2, 'kernel': 'linear'}
# 0.490 for {'C': 0.5, 'degree': 4, 'epsilon': 0.2, 'kernel': 'poly'}
# 0.462 for {'C': 0.5, 'degree': 4, 'epsilon': 0.2, 'kernel': 'rbf'}
# 0.431 for {'C': 0.5, 'degree': 4, 'epsilon': 0.2, 'kernel': 'sigmoid'}
# 0.550 for {'C': 0.5, 'degree': 4, 'epsilon': 0.25, 'kernel': 'linear'}
# 0.490 for {'C': 0.5, 'degree': 4, 'epsilon': 0.25, 'kernel': 'poly'}
# 0.462 for {'C': 0.5, 'degree': 4, 'epsilon': 0.25, 'kernel': 'rbf'}
# 0.431 for {'C': 0.5, 'degree': 4, 'epsilon': 0.25, 'kernel': 'sigmoid'}
# 0.550 for {'C': 0.5, 'degree': 4, 'epsilon': 0.3, 'kernel': 'linear'}
# 0.490 for {'C': 0.5, 'degree': 4, 'epsilon': 0.3, 'kernel': 'poly'}
# 0.462 for {'C': 0.5, 'degree': 4, 'epsilon': 0.3, 'kernel': 'rbf'}
# 0.431 for {'C': 0.5, 'degree': 4, 'epsilon': 0.3, 'kernel': 'sigmoid'}
# 0.550 for {'C': 0.6, 'degree': 2, 'epsilon': 0.1, 'kernel': 'linear'}
# 0.509 for {'C': 0.6, 'degree': 2, 'epsilon': 0.1, 'kernel': 'poly'}
# 0.477 for {'C': 0.6, 'degree': 2, 'epsilon': 0.1, 'kernel': 'rbf'}
# 0.449 for {'C': 0.6, 'degree': 2, 'epsilon': 0.1, 'kernel': 'sigmoid'}
# 0.550 for {'C': 0.6, 'degree': 2, 'epsilon': 0.15, 'kernel': 'linear'}
# 0.509 for {'C': 0.6, 'degree': 2, 'epsilon': 0.15, 'kernel': 'poly'}
# 0.477 for {'C': 0.6, 'degree': 2, 'epsilon': 0.15, 'kernel': 'rbf'}
# 0.448 for {'C': 0.6, 'degree': 2, 'epsilon': 0.15, 'kernel': 'sigmoid'}
# 0.550 for {'C': 0.6, 'degree': 2, 'epsilon': 0.2, 'kernel': 'linear'}
# 0.509 for {'C': 0.6, 'degree': 2, 'epsilon': 0.2, 'kernel': 'poly'}
# 0.477 for {'C': 0.6, 'degree': 2, 'epsilon': 0.2, 'kernel': 'rbf'}
# 0.448 for {'C': 0.6, 'degree': 2, 'epsilon': 0.2, 'kernel': 'sigmoid'}
# 0.550 for {'C': 0.6, 'degree': 2, 'epsilon': 0.25, 'kernel': 'linear'}
# 0.509 for {'C': 0.6, 'degree': 2, 'epsilon': 0.25, 'kernel': 'poly'}
# 0.477 for {'C': 0.6, 'degree': 2, 'epsilon': 0.25, 'kernel': 'rbf'}
# 0.448 for {'C': 0.6, 'degree': 2, 'epsilon': 0.25, 'kernel': 'sigmoid'}
# 0.550 for {'C': 0.6, 'degree': 2, 'epsilon': 0.3, 'kernel': 'linear'}
# 0.509 for {'C': 0.6, 'degree': 2, 'epsilon': 0.3, 'kernel': 'poly'}
# 0.477 for {'C': 0.6, 'degree': 2, 'epsilon': 0.3, 'kernel': 'rbf'}
# 0.448 for {'C': 0.6, 'degree': 2, 'epsilon': 0.3, 'kernel': 'sigmoid'}
# 0.550 for {'C': 0.6, 'degree': 3, 'epsilon': 0.1, 'kernel': 'linear'}
# 0.508 for {'C': 0.6, 'degree': 3, 'epsilon': 0.1, 'kernel': 'poly'}
# 0.477 for {'C': 0.6, 'degree': 3, 'epsilon': 0.1, 'kernel': 'rbf'}
# 0.449 for {'C': 0.6, 'degree': 3, 'epsilon': 0.1, 'kernel': 'sigmoid'}
# 0.550 for {'C': 0.6, 'degree': 3, 'epsilon': 0.15, 'kernel': 'linear'}
# 0.508 for {'C': 0.6, 'degree': 3, 'epsilon': 0.15, 'kernel': 'poly'}
# 0.477 for {'C': 0.6, 'degree': 3, 'epsilon': 0.15, 'kernel': 'rbf'}
# 0.448 for {'C': 0.6, 'degree': 3, 'epsilon': 0.15, 'kernel': 'sigmoid'}
# 0.550 for {'C': 0.6, 'degree': 3, 'epsilon': 0.2, 'kernel': 'linear'}
# 0.508 for {'C': 0.6, 'degree': 3, 'epsilon': 0.2, 'kernel': 'poly'}
# 0.477 for {'C': 0.6, 'degree': 3, 'epsilon': 0.2, 'kernel': 'rbf'}
# 0.448 for {'C': 0.6, 'degree': 3, 'epsilon': 0.2, 'kernel': 'sigmoid'}
# 0.550 for {'C': 0.6, 'degree': 3, 'epsilon': 0.25, 'kernel': 'linear'}
# 0.508 for {'C': 0.6, 'degree': 3, 'epsilon': 0.25, 'kernel': 'poly'}
# 0.477 for {'C': 0.6, 'degree': 3, 'epsilon': 0.25, 'kernel': 'rbf'}
# 0.448 for {'C': 0.6, 'degree': 3, 'epsilon': 0.25, 'kernel': 'sigmoid'}
# 0.550 for {'C': 0.6, 'degree': 3, 'epsilon': 0.3, 'kernel': 'linear'}
# 0.508 for {'C': 0.6, 'degree': 3, 'epsilon': 0.3, 'kernel': 'poly'}
# 0.477 for {'C': 0.6, 'degree': 3, 'epsilon': 0.3, 'kernel': 'rbf'}
# 0.448 for {'C': 0.6, 'degree': 3, 'epsilon': 0.3, 'kernel': 'sigmoid'}
# 0.550 for {'C': 0.6, 'degree': 4, 'epsilon': 0.1, 'kernel': 'linear'}
# 0.500 for {'C': 0.6, 'degree': 4, 'epsilon': 0.1, 'kernel': 'poly'}
# 0.477 for {'C': 0.6, 'degree': 4, 'epsilon': 0.1, 'kernel': 'rbf'}
# 0.449 for {'C': 0.6, 'degree': 4, 'epsilon': 0.1, 'kernel': 'sigmoid'}
# 0.550 for {'C': 0.6, 'degree': 4, 'epsilon': 0.15, 'kernel': 'linear'}
# 0.500 for {'C': 0.6, 'degree': 4, 'epsilon': 0.15, 'kernel': 'poly'}
# 0.477 for {'C': 0.6, 'degree': 4, 'epsilon': 0.15, 'kernel': 'rbf'}
# 0.448 for {'C': 0.6, 'degree': 4, 'epsilon': 0.15, 'kernel': 'sigmoid'}
# 0.550 for {'C': 0.6, 'degree': 4, 'epsilon': 0.2, 'kernel': 'linear'}
# 0.500 for {'C': 0.6, 'degree': 4, 'epsilon': 0.2, 'kernel': 'poly'}
# 0.477 for {'C': 0.6, 'degree': 4, 'epsilon': 0.2, 'kernel': 'rbf'}
# 0.448 for {'C': 0.6, 'degree': 4, 'epsilon': 0.2, 'kernel': 'sigmoid'}
# 0.550 for {'C': 0.6, 'degree': 4, 'epsilon': 0.25, 'kernel': 'linear'}
# 0.500 for {'C': 0.6, 'degree': 4, 'epsilon': 0.25, 'kernel': 'poly'}
# 0.477 for {'C': 0.6, 'degree':
 'epsilon': 0.3, 'kernel': 'linear'}
# 0.522 for {'C': 0.9, 'degree': 3, 'epsilon': 0.3, 'kernel': 'poly'}
# 0.502 for {'C': 0.9, 'degree': 3, 'epsilon': 0.3, 'kernel': 'rbf'}
# 0.479 for {'C': 0.9, 'degree': 3, 'epsilon': 0.3, 'kernel': 'sigmoid'}
# 0.549 for {'C': 0.9, 'degree': 4, 'epsilon': 0.1, 'kernel': 'linear'}
# 0.517 for {'C': 0.9, 'degree': 4, 'epsilon': 0.1, 'kernel': 'poly'}
# 0.501 for {'C': 0.9, 'degree': 4, 'epsilon': 0.1, 'kernel': 'rbf'}
# 0.479 for {'C': 0.9, 'degree': 4, 'epsilon': 0.1, 'kernel': 'sigmoid'}
# 0.550 for {'C': 0.9, 'degree': 4, 'epsilon': 0.15, 'kernel': 'linear'}
# 0.517 for {'C': 0.9, 'degree': 4, 'epsilon': 0.15, 'kernel': 'poly'}
# 0.502 for {'C': 0.9, 'degree': 4, 'epsilon': 0.15, 'kernel': 'rbf'}
# 0.479 for {'C': 0.9, 'degree': 4, 'epsilon': 0.15, 'kernel': 'sigmoid'}
# 0.550 for {'C': 0.9, 'degree': 4, 'epsilon': 0.2, 'kernel': 'linear'}
# 0.517 for {'C': 0.9, 'degree': 4, 'epsilon': 0.2, 'kernel': 'poly'}
# 0.502 for {'C': 0.9, 'degree': 4, 'epsilon': 0.2, 'kernel': 'rbf'}
# 0.479 for {'C': 0.9, 'degree': 4, 'epsilon': 0.2, 'kernel': 'sigmoid'}
# 0.550 for {'C': 0.9, 'degree': 4, 'epsilon': 0.25, 'kernel': 'linear'}
# 0.517 for {'C': 0.9, 'degree': 4, 'epsilon': 0.25, 'kernel': 'poly'}
# 0.502 for {'C': 0.9, 'degree': 4, 'epsilon': 0.25, 'kernel': 'rbf'}
# 0.478 for {'C': 0.9, 'degree': 4, 'epsilon': 0.25, 'kernel': 'sigmoid'}
# 0.550 for {'C': 0.9, 'degree': 4, 'epsilon': 0.3, 'kernel': 'linear'}
# 0.517 for {'C': 0.9, 'degree': 4, 'epsilon': 0.3, 'kernel': 'poly'}
# 0.502 for {'C': 0.9, 'degree': 4, 'epsilon': 0.3, 'kernel': 'rbf'}
# 0.479 for {'C': 0.9, 'degree': 4, 'epsilon': 0.3, 'kernel': 'sigmoid'}
# 0.549 for {'C': 1.0, 'degree': 2, 'epsilon': 0.1, 'kernel': 'linear'}
# 0.525 for {'C': 1.0, 'degree': 2, 'epsilon': 0.1, 'kernel': 'poly'}
# 0.506 for {'C': 1.0, 'degree': 2, 'epsilon': 0.1, 'kernel': 'rbf'}
# 0.484 for {'C': 1.0, 'degree': 2, 'epsilon': 0.1, 'kernel': 'sigmoid'}
# 0.550 for {'C': 1.0, 'degree': 2, 'epsilon': 0.15, 'kernel': 'linear'}
# 0.525 for {'C': 1.0, 'degree': 2, 'epsilon': 0.15, 'kernel': 'poly'}
# 0.507 for {'C': 1.0, 'degree': 2, 'epsilon': 0.15, 'kernel': 'rbf'}
# 0.484 for {'C': 1.0, 'degree': 2, 'epsilon': 0.15, 'kernel': 'sigmoid'}
# 0.550 for {'C': 1.0, 'degree': 2, 'epsilon': 0.2, 'kernel': 'linear'}
# 0.525 for {'C': 1.0, 'degree': 2, 'epsilon': 0.2, 'kernel': 'poly'}
# 0.507 for {'C': 1.0, 'degree': 2, 'epsilon': 0.2, 'kernel': 'rbf'}
# 0.484 for {'C': 1.0, 'degree': 2, 'epsilon': 0.2, 'kernel': 'sigmoid'}
# 0.550 for {'C': 1.0, 'degree': 2, 'epsilon': 0.25, 'kernel': 'linear'}
# 0.525 for {'C': 1.0, 'degree': 2, 'epsilon': 0.25, 'kernel': 'poly'}
# 0.507 for {'C': 1.0, 'degree': 2, 'epsilon': 0.25, 'kernel': 'rbf'}
# 0.484 for {'C': 1.0, 'degree': 2, 'epsilon': 0.25, 'kernel': 'sigmoid'}
# 0.549 for {'C': 1.0, 'degree': 2, 'epsilon': 0.3, 'kernel': 'linear'}
# 0.525 for {'C': 1.0, 'degree': 2, 'epsilon': 0.3, 'kernel': 'poly'}
# 0.507 for {'C': 1.0, 'degree': 2, 'epsilon': 0.3, 'kernel': 'rbf'}
# 0.484 for {'C': 1.0, 'degree': 2, 'epsilon': 0.3, 'kernel': 'sigmoid'}
# 0.549 for {'C': 1.0, 'degree': 3, 'epsilon': 0.1, 'kernel': 'linear'}
# 0.525 for {'C': 1.0, 'degree': 3, 'epsilon': 0.1, 'kernel': 'poly'}
# 0.506 for {'C': 1.0, 'degree': 3, 'epsilon': 0.1, 'kernel': 'rbf'}
# 0.484 for {'C': 1.0, 'degree': 3, 'epsilon': 0.1, 'kernel': 'sigmoid'}
# 0.550 for {'C': 1.0, 'degree': 3, 'epsilon': 0.15, 'kernel': 'linear'}
# 0.525 for {'C': 1.0, 'degree': 3, 'epsilon': 0.15, 'kernel': 'poly'}
# 0.507 for {'C': 1.0, 'degree': 3, 'epsilon': 0.15, 'kernel': 'rbf'}
# 0.484 for {'C': 1.0, 'degree': 3, 'epsilon': 0.15, 'kernel': 'sigmoid'}
# 0.550 for {'C': 1.0, 'degree': 3, 'epsilon': 0.2, 'kernel': 'linear'}
# 0.525 for {'C': 1.0, 'degree': 3, 'epsilon': 0.2, 'kernel': 'poly'}
# 0.507 for {'C': 1.0, 'degree': 3, 'epsilon': 0.2, 'kernel': 'rbf'}
# 0.484 for {'C': 1.0, 'degree': 3, 'epsilon': 0.2, 'kernel': 'sigmoid'}
# 0.550 for {'C': 1.0, 'degree': 3, 'epsilon': 0.25, 'kernel': 'linear'}
# 0.525 for {'C': 1.0, 'degree': 3, 'epsilon': 0.25, 'kernel': 'poly'}
# 0.507 for {'C': 1.0, 'degree': 3, 'epsilon': 0.25, 'kernel': 'rbf'}
# 0.484 for {'C': 1.0, 'degree': 3, 'epsilon': 0.25, 'kernel': 'sigmoid'}
# 0.549 for {'C': 1.0, 'degree': 3, 'epsilon': 0.3, 'kernel': 'linear'}
# 0.525 for {'C': 1.0, 'degree': 3, 'epsilon': 0.3, 'kernel': 'poly'}
# 0.507 for {'C': 1.0, 'degree': 3, 'epsilon': 0.3, 'kernel': 'rbf'}
# 0.484 for {'C': 1.0, 'degree': 3, 'epsilon': 0.3, 'kernel': 'sigmoid'}
# 0.549 for {'C': 1.0, 'degree': 4, 'epsilon': 0.1, 'kernel': 'linear'}
# 0.520 for {'C': 1.0, 'degree': 4, 'epsilon': 0.1, 'kernel': 'poly'}
# 0.506 for {'C': 1.0, 'degree': 4, 'epsilon': 0.1, 'kernel': 'rbf'}
# 0.484 for {'C': 1.0, 'degree': 4, 'epsilon': 0.1, 'kernel': 'sigmoid'}
# 0.550 for {'C': 1.0, 'degree': 4, 'epsilon': 0.15, 'kernel': 'linear'}
# 0.520 for {'C': 1.0, 'degree': 4, 'epsilon': 0.15, 'kernel': 'poly'}
# 0.507 for {'C': 1.0, 'degree': 4, 'epsilon': 0.15, 'kernel': 'rbf'}
# 0.484 for {'C': 1.0, 'degree': 4, 'epsilon': 0.15, 'kernel': 'sigmoid'}
# 0.550 for {'C': 1.0, 'degree': 4, 'epsilon': 0.2, 'kernel': 'linear'}
# 0.520 for {'C': 1.0, 'degree': 4, 'epsilon': 0.2, 'kernel': 'poly'}
# 0.507 for {'C': 1.0, 'degree': 4, 'epsilon': 0.2, 'kernel': 'rbf'}
# 0.484 for {'C': 1.0, 'degree': 4, 'epsilon': 0.2, 'kernel': 'sigmoid'}
# 0.550 for {'C': 1.0, 'degree': 4, 'epsilon': 0.25, 'kernel': 'linear'}
# 0.520 for {'C': 1.0, 'degree': 4, 'epsilon': 0.25, 'kernel': 'poly'}
# 0.507 for {'C': 1.0, 'degree': 4, 'epsilon': 0.25, 'kernel': 'rbf'}
# 0.484 for {'C': 1.0, 'degree': 4, 'epsilon': 0.25, 'kernel': 'sigmoid'}
# 0.549 for {'C': 1.0, 'degree': 4, 'epsilon': 0.3, 'kernel': 'linear'}
# 0.520 for {'C': 1.0, 'degree': 4, 'epsilon': 0.3, 'kernel': 'poly'}
# 0.507 for {'C': 1.0, 'degree': 4, 'epsilon': 0.3, 'kernel': 'rbf'}
# 0.484 for {'C': 1.0, 'degree': 4, 'epsilon': 0.3, 'kernel': 'sigmoid'}
# Best parameters set found on development set:
#
# {'C': 0.6, 'degree': 2, 'epsilon': 0.3, 'kernel': 'linear'}

# %%
# R-squaer and mean square error
clf=SVR(C=0.6, degree=2, epsilon=0.3, kernel="linear")
clf.fit(xTrain, yTrain)
yHat = clf.predict(xTest)
print("r2_score:")
print(r2_score(yTest, yHat))
print("mean square error:")
print(mean_squared_error(yTest, yHat, squared=False))
# Out:
# r2_score:
# 0.47510730161827097
# mean square error:
# 9.532687769370472

# %%
# model analysis
# We will choose 50 features with the largest constants in linear regression model
# They are the 50 most important features in the model
print("feature coefficients of the model")
print(clf.coef_)
print()
